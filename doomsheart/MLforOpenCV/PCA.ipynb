# %% [markdown]
# PCA (Principal Component Analysis)
#
# multivariate Gaussian

# %%
import numpy as np
mean = [20, 20]
cov = [[5, 0],[25, 25]]
x, y = np.random.multivariate_normal(mean, cov, 1000).T
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: covariance is not positive-semidefinite.
#   after removing the cwd from sys.path.

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
plt.plot(x, y, 'o', zorder=1)
plt.axis([0, 40, 0, 40])
plt.xlabel('feature 1')
plt.ylabel('feature 2')
# Out:
# Text(0,0.5,'feature 2')

# %%
X = np.vstack((x, y)).T

# %%
import cv2 as cv
mu, eig = cv.PCACompute(X, np.array([]))
eig
# Out:
# array([[ 0.72419932,  0.68959071],
#        [-0.68959071,  0.72419932]])

# %%
plt.plot(x, y, 'o', zorder=1)
plt.quiver(mean[0], mean[1], eig[:, 0], eig[:, 1], zorder=3, scale=0.2, 
           units='xy')
plt.text(mean[0] + 5 * eig[0, 0], mean[1] + 5 * eig[0, 1], 'u1', zorder=5, 
         fontsize=16, bbox=dict(facecolor='white', alpha=0.6) )
plt.text(mean[0] + 7 * eig[1, 0], mean[1] + 4 * eig[1, 1], 'u2', zorder=5, 
         fontsize=16, bbox=dict(facecolor='white', alpha=0.6))
plt.axis([0, 40, 0, 40])
plt.xlabel('feature 1')
plt.ylabel('feature 2')
# Out:
# Text(0,0.5,'feature 2')

# %%
# rotate the data
X2 = cv.PCAProject(X, mu, eig)

# %%
plt.plot(X2[:, 0], X2[:, 1], 'o')
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.axis([-20, 20, -10, 10])
# Out:
# [-20, 20, -10, 10]

# %%
from sklearn import decomposition

# %%
ica = decomposition.FastICA()

# %%
X2 = ica.fit_transform(X)

# %%
plt.plot(X2[:, 0], X2[:, 1], 'o')
plt.xlabel('first independent component')
plt.ylabel('sexond independent component')
plt.axis([-0.2, 0.2, -0.2, 0.2])
# Out:
# [-0.2, 0.2, -0.2, 0.2]

# %%
nmf = decomposition.NMF()

# %%
X2 = nmf.fit_transform(X)

# %%
plt.plot(X2[:, 0], X2[:, 1], 'o')
plt.xlabel('first non-negative component')
plt.ylabel('second non-negative component')
plt.axis([-5, 15, -5, 15])
# Out:
# [-5, 15, -5, 15]
